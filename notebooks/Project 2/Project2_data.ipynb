# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("AmesHousing.csv")

# %%
tmp = pd.get_dummies(data[		[ 'Gr Liv Area', 
		'Overall Qual', 
		'Year Built', 
		'Year Remod/Add', 
		'Neighborhood',  
		'Bsmt Qual', 
		'BsmtFin Type 1', 
		'Kitchen Qual', 
		'Garage Area',
		'Fireplaces',
		'Total Bsmt SF',
		'Lot Shape',
        'SalePrice']], dtype=float)
sample  = tmp[		[ 'Gr Liv Area', 
		'Overall Qual', 
		'Year Built', 
		'Year Remod/Add', 
		'Neighborhood_NridgHt',  
		'Bsmt Qual_Ex', 
		'BsmtFin Type 1_GLQ', 
		'Kitchen Qual_Ex', 
		'Garage Area',
		'Fireplaces',
		'Total Bsmt SF',
		'Lot Shape_IR1',
        'SalePrice']]

# %%
corr = tmp.corr()
corr.style.background_gradient( cmap = 'coolwarm' )
# Out:
# <style type="text/css">
# ...

# %% [raw]
# Neighborhood_NridgHt, Foundation_PConc, Bsmt Qual_Ex, BsmtFin Type 1_GLQ, Full Bath
